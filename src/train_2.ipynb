# %% [markdown]
# # TRAIN MODEL

# %%
import pandas as pd

# %%
df_train = pd.read_csv("../data/train/train_data.csv")

# %%
df_train.head()
# Out:
#    location_id        date  rainfall  temperature  humidity     pressure  \
# 0            1  2001-07-07       0.5    30.200001      68.0   998.400024
# 1            1  2001-07-08      38.0    28.400000      82.0  1003.099976
# 2            1  2001-07-09       6.7    28.000000      80.0  1006.400024
# 3            1  2001-07-10       0.2    28.200001      79.0  1006.200012
# 4            1  2001-07-11       0.8    28.600000      80.0  1004.700012
#
#    wind_speed  river_discharge  flood  month  rainfall_3d  rainfall_7d  \
# 0        23.1             0.36      0      7          0.5         16.3
# 1         6.2             0.70      0      7         38.5         54.3
# 2         8.1             1.28      0      7         45.2         60.8
# 3         9.2             0.92      0      7         44.9         59.2
# 4         9.1             0.58      0      7          7.7         46.2
#
#    discharge_change_1d  target_d1  target_d2  target_d3
# ...

# %%
df_train.shape
# Out:
# (18268, 16)

# %%
df_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18268 entries, 0 to 18267
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   location_id          18268 non-null  int64
#  1   date                 18268 non-null  str
#  2   rainfall             18268 non-null  float64
#  3   temperature          18268 non-null  float64
#  4   humidity             18268 non-null  float64
#  5   pressure             18268 non-null  float64
#  6   wind_speed           18268 non-null  float64
#  7   river_discharge      18268 non-null  float64
#  8   flood                18268 non-null  int64
#  9   month                18268 non-null  int64
#  10  rainfall_3d          18268 non-null  float64
#  11  rainfall_7d          18268 non-null  float64
#  12  discharge_change_1d  18268 non-null  float64
#  13  target_d1            18268 non-null  int64
#  14  target_d2            18268 non-null  int64
# ...

# %%
df_train['date'] = pd.to_datetime(df_train['date'])

df_train.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 18268 entries, 0 to 18267
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   location_id          18268 non-null  int64
#  1   date                 18268 non-null  datetime64[us]
#  2   rainfall             18268 non-null  float64
#  3   temperature          18268 non-null  float64
#  4   humidity             18268 non-null  float64
#  5   pressure             18268 non-null  float64
#  6   wind_speed           18268 non-null  float64
#  7   river_discharge      18268 non-null  float64
#  8   flood                18268 non-null  int64
#  9   month                18268 non-null  int64
#  10  rainfall_3d          18268 non-null  float64
#  11  rainfall_7d          18268 non-null  float64
#  12  discharge_change_1d  18268 non-null  float64
#  13  target_d1            18268 non-null  int64
#  14  target_d2            18268 non-null  int64
# ...
